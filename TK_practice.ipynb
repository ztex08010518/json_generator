# %%
from tkinter import *

# %%
root = Tk()

var_vpWhiteList = BooleanVar()
var_appPatrol = BooleanVar()
var_webReputationService = BooleanVar()
var_urlWhiteBlackList = BooleanVar()
var_appWhiteBlackList = BooleanVar()
var_appAuth = BooleanVar()
var_searchEngine = BooleanVar()
var_safeSearchDevices = BooleanVar()
var_scheduledInternetBlocking = BooleanVar()


def var_states():
   print("vpWhiteList : %d" % var_vpWhiteList.get(),
         "appPatrol : %d" % var_appPatrol.get(),
         "webReputationService : %d" % var_webReputationService.get(),
         "urlWhiteBlackList : %d" % var_urlWhiteBlackList.get(),
         "appWhiteBlackList : %d" % var_appWhiteBlackList.get(),
         "appAuth : %d" % var_appAuth.get(),
         "searchEngine : %d" % var_searchEngine.get(),
         "safeSearchDevices : %d" % var_safeSearchDevices.get(),
         "scheduledInternetBlocking : %d" % var_scheduledInternetBlocking.get()
     )

class MyDialog():
    tmp = []
    def __init__(self, parent):
        top = self.top = tk.Toplevel(parent)
        Label(top, text="Please input all the parameters").grid(row=0, sticky=W)        
        if var_vpWhiteList.get():
            Label(top, text = "vpWhiteList").grid(row=1, sticky = W)
        if var_appPatrol.get():
            Label(top, text = "appPatrol").grid(row=2, sticky = W)
        if var_webReputationService.get():
            Label(top, text = "webReputationService").grid(row=3, sticky = W)
        if var_urlWhiteBlackList.get():
            Label(top, text = "urlWhiteBlackList").grid(row=4, sticky = W)
        if var_appWhiteBlackList.get():
            Label(top, text = "appWhiteBlackList").grid(row=5, sticky = W)
        if var_appAuth.get():
            Label(top, text = "appAuth").grid(row=6, sticky = W)
        if var_searchEngine.get():
            Label(top, text = "searchEngine").grid(row=7, sticky = W)
        if var_safeSearchDevices.get():
            Label(top, text = "safeSearchDevices").grid(row=8, sticky = W)
        if var_scheduledInternetBlocking.get():
            Label(top, text = "scheduledInternetBlocking").grid(row=9, sticky = W)
        
        
        
        

    def send(self):
        self.username = self.myEntryBox.get()
        self.top.destroy()
        
def onClick():
    inputDialog = MyDialog(root)
    root.wait_window(inputDialog.top)
    #print('Username: ', inputDialog.username)



Label(root, text="Which function do you need?").grid(row=0, sticky=W)
Checkbutton(root, text="vpWhiteList", variable=var_vpWhiteList).grid(row=1, sticky=W)
Checkbutton(root, text="appPatrol", variable=var_appPatrol).grid(row=2, sticky=W)
Checkbutton(root, text="webReputationService", variable=var_webReputationService).grid(row=3, sticky=W)
Checkbutton(root, text="urlWhiteBlackList", variable=var_urlWhiteBlackList).grid(row=4, sticky=W)
Checkbutton(root, text="appWhiteBlackList", variable=var_appWhiteBlackList).grid(row=5, sticky=W)
Checkbutton(root, text="appAuth", variable=var_appAuth).grid(row=6, sticky=W)
Checkbutton(root, text="searchEngine", variable=var_searchEngine).grid(row=7, sticky=W)
Checkbutton(root, text="safeSearchDevices", variable=var_safeSearchDevices).grid(row=8, sticky=W)
Checkbutton(root, text="scheduledInternetBlocking", variable=var_scheduledInternetBlocking).grid(row=9, sticky=W)
Button(root, text='Show', command=var_states).grid(row=10, sticky=W, pady=4)
Button(root, text='Next', command=onClick).grid(row=10, sticky=E, pady=4)

root.lift()
root.attributes('-topmost',True)
root.after_idle(root.attributes,'-topmost',False)
mainloop()

# %% [markdown]
# import tkinter as tk
#
# class MyDialog:
#
#     def __init__(self, parent):
#         top = self.top = tk.Toplevel(parent)
#         self.myLabel = tk.Label(top, text='Enter your username below')
#         self.myLabel.pack()
#         self.myEntryBox = tk.Entry(top)
#         self.myEntryBox.pack()
#         self.mySubmitButton = tk.Button(top, text='Submit', command=self.send)
#         self.mySubmitButton.pack()
#
#     def send(self):
#         self.username = self.myEntryBox.get()
#         self.top.destroy()
#
# def onClick():
#     inputDialog = MyDialog(root)
#     root.wait_window(inputDialog.top)
#     print('Username: ', inputDialog.username)
#
# root = tk.Tk()
# mainLabel = tk.Label(root, text='Example for pop up input box')
# mainLabel.pack()
#
# mainButton = tk.Button(root, text='Click me', command=onClick)
# mainButton.pack()
#
# root.mainloop()
